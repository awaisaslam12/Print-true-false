# %%
name = "awais"
age = 17
print("My name is",name, "I am ",age)
# Out:
# My name is awais I am  17

# %%
# Out:
#  uiuw
#  buwbf
# Name of candidate uiuw Age of candidate buwbf

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 name = intput("my name is:")
#       2 while True:
#       3     try:
#
# NameError: name 'intput' is not defined

# %%
name = input("my name is:")
while True:
    try:
        age = int(input("my age is:"))
        break
    except:
        print("please enter a valid age")
# Out:
# my name is: awais
# my age is: 18

# %%
name = input("enter your name :")
while True:
    try:
        age = int(input("your age is :"))
        break
    except:
        print("no")
# Out:
# enter your name : awais
# your age is : u
# no
# your age is : 12\
# no
# your age is : 23

# %%
name = input("enter your name:")
while True:
    try:
        age = int(input("age is :"))
        if age < 10 or age > 120:
            print("try again")
        else:
            break
    except:
        print("enter valid age")

print("my name is  :",name)
print("age accepted:", age)

# %%
name = input("enter your name:")
while True:
    try:
        age = int(input("age is :"))
        if age < 10 or age > 120:
            print("try again")
        else:
            break
    except:
        print("enter valid age")

print("my name is  :",name)
print("age accepted:", age)
