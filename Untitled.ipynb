# %%
text="ice cream"
text[0]
# Out:
# 'i'

# %%
text[0:3]
# Out:
# 'ice'

# %%
text[4:9]
# Out:
# 'cream'

# %%
text[2:]
# Out:
# 'e cream'

# %%
adress='''1 purpule street new york'''
print (adress)
# Out:
# 1 purpule street new york

# %%
item1="bread"
item2="pasta"
item3="fruits"
items=['bread','pasta','fruits','veggies']
print (items[0])
items[2]
"read" in items
# Out:
# bread
# False
